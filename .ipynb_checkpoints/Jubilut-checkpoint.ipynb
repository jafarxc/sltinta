# %%
import pandas as pd
import pandera.pandas as pa
import random

# %%
x = f"{random.randint(0, 999):03d}"
y = f"{random.randint(0, 999):03d}"
z = f"{random.randint(0, 999):03d}"
w = f"{random.randint(0, 99):02d}"

print(f"{x}.{y}.{z}-{w}")
# Out:
# 108.026.268-45

# %%
while True:
    print(random.randint(0,10000000000000000))
